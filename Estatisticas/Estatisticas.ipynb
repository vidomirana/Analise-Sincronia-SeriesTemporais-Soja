# %% [markdown]
# # Testes de Estacionariedade

# %%
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller, kpss
import numpy as np
import pandas as pd
from yahoofinancials import YahooFinancials
import matplotlib.pyplot as plt

# %%
# Exemplo de teste Dickey-Fuller
data = np.random.rand(100)
result = adfuller(data)
print('Estatística do teste de Dickey-Fuller:', result[0])
print('Valor p:', result[1])
# Out:
# Estatística do teste de Dickey-Fuller: -7.126670456656485
# Valor p: 3.605305167070725e-10

# %%
result
# Out:
# (-7.126670456656485,
#  3.605305167070725e-10,
#  2,
#  97,
#  {'1%': -3.4996365338407074,
#   '5%': -2.8918307730370025,
#   '10%': -2.5829283377617176},
#  34.701346813894816)

# %% [markdown]
# ## Aplicando o teste de Dickey-Fuller na série de Soja (Yahoo Finance)

# %%
lista_codigos = ['ZS=F']  #soja grão
dados_yahoo = YahooFinancials(lista_codigos)
preco_diario = dados_yahoo.get_historical_price_data('1999-01-01', '2024-02-07', 'daily')
precos_soja = pd.DataFrame({a: {x['formatted_date']: x['adjclose'] for x in preco_diario[a]['prices']} for a in lista_codigos})

# Pré-processamento
precos_soja.reset_index(inplace=True)
precos_soja = precos_soja.rename(columns={'index':'Data'}).copy()
precos_soja.set_index('Data', inplace=True)
precos_soja.index = pd.to_datetime(precos_soja.index)

precos_soja
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 lista_codigos = ['ZS=F']  #soja grão
#       2 dados_yahoo = YahooFinancials(lista_codigos)
# ----> 3 preco_diario = dados_yahoo.get_historical_price_data('1999-01-01', '2024-02-07', 'daily')
#       4 precos_soja = pd.DataFrame({a: {x['formatted_date']: x['adjclose'] for x in preco_diario[a]['prices']} for a in lista_codigos})
#       6 # Pré-processamento
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\yahoofinancials\yf.py:163, in YahooFinancials.get_historical_price_data(self, start_date, end_date, time_interval)
#     161 end = self.format_date(end_date)
#     162 hist_obj = {'start': start, 'end': end, 'interval': interval_code}
# --> 163 return self.get_stock_data('history', hist_obj=hist_obj)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\yahoofinancials\data.py:647, in YahooFinanceData.get_stock_data(self, statement_type, tech_type, report_name, hist_obj)
#     645 for tick in self.ticker:
#     646     try:
# --> 647         dict_ent = self._create_dict_ent(tick, statement_type, tech_type, report_name, hist_obj)
#     648         data.update(dict_ent)
#     649     except ManagedException:
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\yahoofinancials\data.py:528, in YahooFinanceData._create_dict_ent(self, up_ticker, statement_type, tech_type, report_name, hist_obj)
#     526 if statement_type == 'history':
#     527     try:
# --> 528         cleaned_re_data = self._recursive_api_request(hist_obj, up_ticker)
#     529     except KeyError:
#     530         cleaned_re_data = None
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\yahoofinancials\data.py:510, in YahooFinanceData._recursive_api_request(self, hist_obj, up_ticker, clean, i)
#     508 v = "2"
#     509 if clean:
# --> 510     re_data = self._clean_api_data(self._build_api_url(hist_obj, up_ticker, v))
#     511     cleaned_re_data = self._clean_historical_data(re_data)
#     512     if cleaned_re_data is not None:
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\yahoofinancials\data.py:467, in YahooFinanceData._clean_api_data(self, api_url)
#     466 def _clean_api_data(self, api_url):
# --> 467     raw_data = self._get_api_data(api_url)
#     468     ret_obj = {}
#     469     ret_obj.update({'eventsData': []})
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\yahoofinancials\data.py:447, in YahooFinanceData._get_api_data(self, api_url, tries)
#     445         cur_url = cur_url.replace("query1.", "query2.")
#     446 urlopener = UrlOpener(self.session)
# --> 447 response = urlopener.open(cur_url, proxy=self._get_proxy(), timeout=self.timeout)
#     448 if response.status_code == 200:
#     449     res_content = response.text
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\yahoofinancials\data.py:43, in UrlOpener.open(self, url, request_headers, params, proxy, timeout)
#      42 def open(self, url, request_headers=None, params=None, proxy=None, timeout=30):
# ---> 43     response = self._session_manager.cache_get(
#      44         url=url,
#      45         params=params,
#      46         proxy=proxy,
#      47         timeout=timeout,
#      48         user_agent_headers=request_headers or self.request_headers
#      49     )
#      50     return response
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\yahoofinancials\sessions.py:135, in lru_cache_freezeargs.<locals>.wrapped(*args, **kwargs)
#     133 args = tuple([tuple(arg) if isinstance(arg, list) else arg for arg in args])
#     134 kwargs = {k: tuple(v) if isinstance(v, list) else v for k, v in kwargs.items()}
# --> 135 return func(*args, **kwargs)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\yahoofinancials\sessions.py:464, in SessionManager.cache_get(self, url, user_agent_headers, params, proxy, timeout)
#     461 @lru_cache_freezeargs
#     462 @lru_cache(maxsize=cache_maxsize)
#     463 def cache_get(self, url, user_agent_headers=None, params=None, proxy=None, timeout=30):
# --> 464     return self.get(url, user_agent_headers, params, proxy, timeout)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\yahoofinancials\sessions.py:428, in SessionManager.get(self, url, user_agent_headers, params, proxy, timeout)
#     426 if 'crumb' in params:
#     427     raise Exception("yahoofinancials: Don't manually add 'crumb' to params dict, let sessions.py handle it")
# --> 428 cookie, crumb, strategy = self._get_cookie_and_crumb()
#     429 if crumb is not None:
#     430     crumbs = {'crumb': crumb}
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\yahoofinancials\sessions.py:413, in SessionManager._get_cookie_and_crumb(self, proxy, timeout)
#     410         cookie, crumb = self._get_cookie_and_crumb_basic(proxy, timeout)
#     411 else:
#     412     # Fallback strategy
# --> 413     cookie, crumb = self._get_cookie_and_crumb_basic(proxy, timeout)
#     414     if cookie is None or crumb is None:
#     415         # Fail
#     416         self._set_cookie_strategy('csrf', have_lock=True)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\yahoofinancials\sessions.py:316, in SessionManager._get_cookie_and_crumb_basic(self, proxy, timeout)
#     315 def _get_cookie_and_crumb_basic(self, proxy, timeout):
# --> 316     cookie = self._get_cookie_basic(proxy, timeout)
#     317     crumb = self._get_crumb_basic(proxy, timeout)
#     318     return cookie, crumb
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\yahoofinancials\sessions.py:263, in SessionManager._get_cookie_basic(self, proxy, timeout)
#     261     logging.debug('yahoofinancials: reusing cookie')
#     262     return self._cookie
# --> 263 self._cookie = self._load_cookie_basic()
#     264 if self._cookie is not None:
#     265     return self._cookie
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\yahoofinancials\sessions.py:250, in SessionManager._load_cookie_basic(self)
#     249 def _load_cookie_basic(self):
# --> 250     cookie_dict = cache.get_cookie_cache().lookup('basic')
#     251     if cookie_dict is None:
#     252         return None
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\yahoofinancials\cache.py:373, in _CookieCache.lookup(self, strategy)
#     371     data = _CookieSchema.get(_CookieSchema.strategy == strategy)
#     372     cookie = _pkl.loads(data.cookie_bytes)
# --> 373     return {'cookie': cookie, 'age': _datetime.datetime.now() - data.fetch_date}
#     374 except _CookieSchema.DoesNotExist:
#     375     return None
#
# TypeError: unsupported operand type(s) for -: 'datetime.datetime' and 'str'

# %%
plt.figure(figsize=(15,6))
plt.plot(precos_soja)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 plt.figure(figsize=(15,6))
# ----> 2 plt.plot(precos_soja)
#       3 plt.show()
#
# NameError: name 'precos_soja' is not defined

# %%
dados_soja = precos_soja.dropna()

# %%
def adf_test(timeseries):
    print("Results of Dickey-Fuller Test:")
    dftest = adfuller(timeseries, autolag="AIC")
    dfoutput = pd.Series(
        dftest[0:4],
        index=[
            "Test Statistic",
            "p-value",
            "#Lags Used",
            "Number of Observations Used",
        ],
    )
    for key, value in dftest[4].items():
        dfoutput[f"Critical Value ({key})"] = value
    print(dfoutput)

# %%
adf_test(dados_soja)    #série não estacionária, p-value > 0.05
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 adf_test(dados_soja)    #série não estacionária, p-value > 0.05
#
# NameError: name 'dados_soja' is not defined

# %% [markdown]
# ## Teste Kwiatkowski-Phillips-Schmidt-Shin (KPSS)

# %%
def kpss_test(x, h0_type='c'):
  indices = ['Estatística do teste', 'valor-p', '# de Lags']
  kpss_test = kpss(x, regression=h0_type, nlags="legacy")
  results = pd.Series(kpss_test[0:3], index=indices)
  print('H0: A série temporal é estacionária (caso valor-p > 0.05)')
  for key, value in kpss_test[3].items():
    results[f'Critical Value ({key})'] = value
  
  return results

# %%
kpss_test(dados_soja) #série não estacionária, p-value < 0.05
# Out:
# H0: A série temporal é estacionária (caso valor-p > 0.05)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15540\699921468.py:3: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   kpss_test = kpss(x, regression=h0_type, nlags="legacy")
# Estatística do teste      7.533753
# valor-p                   0.010000
# # de Lags                34.000000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# dtype: float64

# %% [markdown]
# ## Estatísticas descritivas

# %%
est_soja = dados_soja.describe()
print('Estatísticas descritivas:')
print(est_soja)
# Out:
# Estatísticas descritivas:
#               ZS=F
# count  5884.000000
# mean   1002.868542
# std     337.480799
# min     418.500000
# 25%     751.937500
# 50%     971.500000
# 75%    1308.062500
# max    1771.000000

# %%
media_soja = dados_soja.mean().values
desviop_soja = dados_soja.std().values

plt.figure(figsize=(12,5))
plt.plot(dados_soja, label='Preços Soja', color='black')
plt.axhline(media_soja, color='r', linestyle='dashed', label='Média')
plt.axhline(media_soja + 2*desviop_soja, color='g', linestyle='dashed', label='std+')
plt.axhline(media_soja - 2*desviop_soja, color='b', linestyle='dashed', label='std-')
plt.legend(loc='lower right')
plt.show()   #faz sentido esse plot sendo a série não-estacionária? aqui encaixaria os modelos de samuelson e bachelier?

# %% [markdown]
# ### Boxplot e histograma

# %%
# Criar uma figura com subplots para boxplot e histograma
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))

# Boxplot
ax[0].boxplot(dados_soja, showfliers=True)
ax[0].set_title('Boxplot preços soja')

# Histograma
N = dados_soja.size
bins = int(1 + np.log2(N))  #Regra de Sturges
ax[1].hist(dados_soja, bins=bins, edgecolor='black')
ax[1].set_title('Histograma preços soja')
ax[1].set_ylabel('Frequência')
ax[1].set_xlabel('Preço')

plt.show()

# %% [markdown]
# # Série de Soja Sorriso-MT

# %%
precos = pd.read_excel(r"C:\Users\Lenovo\Documents\MeusProjetos\Analise-Sincronia-SeriesTemporais-Soja\Series_Precos\Sorriso_jan21-set24.xlsx")
precos.set_index('Data', inplace=True)
precos = pd.DataFrame(precos['Valor'])
precos.head()
# Out:
#                  Valor
# Data
# 2021-01-11  151.193366
# 2021-01-12  152.695531
# 2021-01-13  148.774896
# 2021-01-14  148.430713
# 2021-01-15  149.769147

# %%
# %run C:\Users\Lenovo\Documents\MeusProjetos\Analise-Sincronia-SeriesTemporais-Soja\Fatos_Estilizados\Funcoes.ipynb

# %%
adf_test(precos)
# Out:
# Results of Dickey-Fuller Test:
# Série estacionária se p-value < 0.05
# ====================================
# Test Statistic                  -0.965910
# p-value                          0.765494
# #Lags Used                      16.000000
# Number of Observations Used    861.000000
# Critical Value (1%)             -3.437968
# Critical Value (5%)             -2.864903
# Critical Value (10%)            -2.568561
# dtype: float64

# %% [markdown]
# ## Retornos Soja Sorriso-MT

# %%
retornos = precos.pct_change()
retornos.dropna(inplace=True)

retornos.head()
# Out:
#                Valor
# Data
# 2021-01-12  0.009935
# 2021-01-13 -0.025676
# 2021-01-14 -0.002313
# 2021-01-15  0.009017
# 2021-01-18  0.012037

# %%
adf_test(retornos)
# Out:
# Results of Dickey-Fuller Test:
# Série estacionária se p-value < 0.05
# ====================================
# Test Statistic                -7.573686e+00
# p-value                        2.797826e-11
# #Lags Used                     1.500000e+01
# Number of Observations Used    8.610000e+02
# Critical Value (1%)           -3.437968e+00
# Critical Value (5%)           -2.864903e+00
# Critical Value (10%)          -2.568561e+00
# dtype: float64
